# %%
from pathlib import Path

import jax
import xarray as xr


jax.config.update("jax_default_device", jax.devices("gpu")[0])

# %%
datadir = Path("../../data")
dataset_xr = xr.open_dataset(
    datadir / "cubic_2d_train_grf_seed=0.hdf5", engine="h5netcdf", chunks={}
).isel({"t": slice(0, 80)})
dataset_xr
# Out:
# <xarray.Dataset> Size: 400MB
# Dimensions:  (pde: 10, ic: 50, t: 80, dim: 1, x: 50, y: 50, param: 3)
# Coordinates:
#   * t        (t) float32 320B 0.0 0.0005 0.001 0.0015 ... 0.0385 0.039 0.0395
#   * dim      (dim) <U1 4B 'u'
#   * x        (x) float32 200B 0.01 0.03 0.05 0.07 0.09 ... 0.93 0.95 0.97 0.99
#   * y        (y) float32 200B 0.01 0.03 0.05 0.07 0.09 ... 0.93 0.95 0.97 0.99
#   * param    (param) <U1 12B 'a' 'b' 'c'
# Dimensions without coordinates: pde, ic
# Data variables:
#     values   (pde, ic, t, dim, x, y) float32 400MB dask.array<chunksize=(10, 50, 80, 1, 50, 50), meta=np.ndarray>
#     coeffs   (pde, param) float64 240B dask.array<chunksize=(10, 3), meta=np.ndarray>
